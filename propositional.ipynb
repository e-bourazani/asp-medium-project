# %%
# %%clingo --time-limit=300 --opt-mode=optN instances/instance-45-16.lp -
# example_n(X):-example(X,_).
# operator(neg;and;or).
# double_operator(and;or).
# %generate rules for operators and atoms
# {for(ID,T,D)}:-ID=1..size,D=1..size,D>ID,operator(T). % generate operators
# {for(ID,atom,C)}:-ID=1..size,attribute(C). % generate atoms
# %
# %constraints
# %
# :-{for(ID,_,_)}!=1,ID=1..size. % it cant be the case that we have no formula
# :-for(ID,T,D),double_operator(T),D>size-1. % it cant be the case that double operators refer to formulas out of bounds
# :-for(ID,neg,D),D>size. % it cant be the case that neg refers to formulas out of bounds
# :-for(ID,and,D),for(D,atom,A1),for(D+1,atom,A2),A2<=A1.  % it cant be the case that and refers to same atoms in different order
# :-for(ID,or,D),for(D,atom,A1),for(D+1,atom,A2),A2<=A1. % it cant be the case that or refers to same atoms in different order
# :-for(ID,and,D),for(D,T1,A1),for(D+1,atom,A2),operator(T1). % it cant be the case that and refers to non-atoms
# :-for(ID,or,D),for(D,T1,A1),for(D+1,atom,A2),operator(T1). % it cant be the case that or refers to non-atoms
# :-for(ID,T,D),double_operator(T),for(D,T1,A1),for(D+1,neg,A2),double_operator(T1). % it cant be the case that double operators refer to negations
# :-for(ID,T,D),double_operator(T),for(D,and,A1),for(D+1,or,A2). % it cant be the case that double operators refer to different operators
# :-for(ID1,T1,D1),for(ID2,T2,D2),ID1<ID2,operator(T1),operator(T2),ID1!=ID2,D1>=D2. %it cant be the case that operators are not ordered by depth
# :-for(ID1,T1,D1), for(ID2,T2,D2), ID1 < ID2, double_operator(T1),operator(T2), D1+1>=D2. % it cant be the case that double operators are not ordered by depth
# %compute size of atoms as 1
# formula_size(ID,1):-for(ID,atom,_).%size of atoms is 1
# %negation of atoms as size formula they refers to +1
# formula_size(ID,Y):-for(ID,neg,D),formula_size(D,X),Y=X+1,X<size. %size of neg as size of formula it refers +1
# %size of or and and as size of formula they refers +1
# formula_size(ID,T):-for(ID,or,D),formula_size(D,X1),formula_size(D+1,X2),T=X1+X2+1,X1<size,X2<size. %size of or as size of formula it refers + size of formula it refers +1
# formula_size(ID,T):-for(ID,and,D),formula_size(D,X1),formula_size(D+1,X2),T=X1+X2+1,X1<size,X2<size. %size of and as size of formula it refers + size of formula it refers +1
# %check that the size of the formula is the possible max
# :-#max{X:formula_size(1,X)}!=size. % formula size must be the max
# %we store how atoms classify examples
# classifies_pos(ID,X):-for(ID,atom,C),has(X,C),ID<=size.
# classifies_neg(ID,X):-for(ID,atom,C),not has(X,C),example_n(X),ID<=size. %atom does not have the attribute in example
# %we store how negations classify examples
# classifies_pos(ID,X):-for(ID,neg,D),classifies_neg(D,X),ID<=size,D<=size. %negation of a formula that classifies neg is pos
# classifies_neg(ID,X):-for(ID,neg,D),classifies_pos(D,X),ID<=size,D<=size. %negation of a formula that classifies pos is neg
# %we store how "or" classifies examples
# classifies_pos(ID,X):-for(ID,or,D), classifies_pos(D,X),ID<=size,D<=size.
# classifies_pos(ID,X):-for(ID,or,D), classifies_pos(D+1,X),ID<=size,D<=size.
# classifies_neg(ID,X):-for(ID,or,D), classifies_neg(D,X), classifies_neg(D+1,X),ID<=size,D<=size.
# %we store how "and" classifies examples
# classifies_pos(ID,X):-for(ID,and,D), classifies_pos(D,X),classifies_pos(D+1,X),ID<=size,D<=size.
# classifies_neg(ID,X):-for(ID,and,D), classifies_neg(D,X),ID<=size,D<=size.
# classifies_neg(ID,X):-for(ID,and,D), classifies_neg(D+1,X),ID<=size,D<=size.
# %we optimize the number of correct answers
# #maximize{1,X:classifies_pos(1,X),example(X,pos);1,X:classifies_neg(1,X),example(X,neg)}.
# #show for/3.
# Out:
# clingo version 5.8.0
# Reading from instances/instance-45-16.lp ...
# Solving...
# Answer: 1 (Time: 0.607s)
# for(1,or,2) for(2,neg,4) for(3,neg,5) for(4,neg,6) for(6,and,7) for(7,neg,9) for(8,neg,10) for(9,and,11) for(10,neg,13) for(13,and,14) for(15,neg,16) for(5,atom,q) for(11,atom,d) for(12,atom,i) for(14,atom,u) for(16,atom,r)
# Optimization: -19
# Answer: 2 (Time: 0.608s)
# for(1,or,2) for(2,neg,4) for(3,neg,5) for(4,neg,6) for(6,and,7) for(7,neg,9) for(8,neg,10) for(9,and,11) for(10,neg,13) for(13,and,14) for(15,neg,16) for(5,atom,q) for(11,atom,d) for(12,atom,i) for(14,atom,u) for(16,atom,o)
# Optimization: -20
# Answer: 3 (Time: 0.608s)
# for(1,or,2) for(2,neg,4) for(3,neg,5) for(4,neg,6) for(6,and,7) for(7,neg,9) for(8,neg,10) for(9,and,11) for(10,neg,13) for(13,and,14) for(15,neg,16) for(5,atom,q) for(11,atom,d) for(12,atom,i) for(14,atom,g) for(16,atom,n)
# Optimization: -21
# Answer: 4 (Time: 0.609s)
# for(1,or,2) for(2,neg,4) for(3,neg,5) for(4,neg,6) for(6,and,7) for(7,neg,9) for(8,neg,10) for(9,and,11) for(10,neg,13) for(13,and,14) for(15,neg,16) for(5,atom,q) for(11,atom,d) for(12,atom,i) for(14,atom,q) for(16,atom,d)
# Optimization: -22
# Answer: 5 (Time: 0.610s)
# for(1,or,2) for(2,neg,4) for(3,neg,5) for(4,neg,6) for(6,and,7) for(7,neg,9) for(8,neg,10) for(9,and,11) for(10,neg,13) for(13,and,14) for(15,neg,16) for(5,atom,o) for(11,atom,d) for(12,atom,t) for(14,atom,o) for(16,atom,j)
# Optimization: -23
# Answer: 6 (Time: 0.629s)
# for(1,or,2) for(2,neg,4) for(3,neg,5) for(4,neg,6) for(6,and,7) for(7,neg,9) for(8,neg,10) for(9,and,11) for(10,neg,13) for(13,and,14) for(15,neg,16) for(5,atom,j) for(11,atom,d) for(12,atom,p) for(14,atom,m) for(16,atom,o)
# Optimization: -24
# Answer: 7 (Time: 0.633s)
# for(1,or,2) for(2,neg,4) for(3,neg,5) for(4,neg,6) for(6,and,7) for(7,neg,9) for(8,neg,10) for(9,and,11) for(10,neg,13) for(13,and,14) for(15,neg,16) for(5,atom,d) for(11,atom,d) for(12,atom,q) for(14,atom,m) for(16,atom,f)
# Optimization: -25
# Answer: 8 (Time: 0.643s)
# for(1,or,2) for(2,neg,4) for(3,neg,5) for(4,neg,6) for(6,and,7) for(7,neg,9) for(8,neg,10) for(9,and,11) for(10,neg,13) for(13,and,14) for(15,neg,16) for(5,atom,a) for(11,atom,d) for(12,atom,e) for(14,atom,m) for(16,atom,f)
# Optimization: -26
# Answer: 9 (Time: 0.666s)
# for(1,and,2) for(2,neg,4) for(3,neg,5) for(4,or,6) for(5,neg,8) for(6,and,9) for(7,and,11) for(10,neg,13) for(13,neg,14) for(14,neg,15) for(15,neg,16) for(8,atom,p) for(9,atom,t) for(11,atom,a) for(12,atom,b) for(16,atom,h)
# Optimization: -28
# Answer: 10 (Time: 0.666s)
# for(1,and,2) for(2,neg,4) for(3,neg,5) for(4,or,6) for(5,neg,8) for(6,and,9) for(7,and,11) for(10,neg,13) for(13,neg,14) for(14,neg,15) for(15,neg,16) for(8,atom,p) for(9,atom,t) for(11,atom,a) for(12,atom,b) for(16,atom,s)
# Optimization: -29
# Answer: 11 (Time: 0.799s)
# for(1,or,2) for(2,neg,4) for(3,or,5) for(4,neg,7) for(6,neg,8) for(7,and,9) for(8,neg,11) for(9,neg,12) for(10,neg,13) for(12,neg,14) for(13,neg,15) for(15,neg,16) for(5,atom,m) for(11,atom,d) for(14,atom,v) for(16,atom,m)
# Optimization: -30
# Answer: 12 (Time: 0.800s)
# for(1,or,2) for(2,neg,4) for(3,or,5) for(4,neg,7) for(6,neg,8) for(7,and,9) for(8,neg,11) for(9,neg,12) for(10,neg,13) for(12,neg,14) for(13,neg,15) for(15,neg,16) for(5,atom,q) for(11,atom,d) for(14,atom,v) for(16,atom,a)
# Optimization: -33
# Answer: 13 (Time: 0.809s)
# for(1,or,2) for(2,neg,4) for(3,or,5) for(4,neg,7) for(6,neg,8) for(7,and,9) for(8,neg,11) for(9,neg,12) for(10,neg,13) for(12,neg,14) for(13,neg,15) for(15,neg,16) for(5,atom,q) for(11,atom,h) for(14,atom,v) for(16,atom,i)
# Optimization: -34
# Answer: 14 (Time: 0.810s)
# for(1,or,2) for(2,neg,4) for(3,or,5) for(4,neg,7) for(6,neg,8) for(7,and,9) for(8,neg,11) for(9,neg,12) for(10,neg,13) for(12,neg,14) for(13,neg,15) for(15,neg,16) for(5,atom,q) for(11,atom,h) for(14,atom,v) for(16,atom,o)
# Optimization: -35
# Answer: 15 (Time: 0.810s)
# for(1,or,2) for(2,neg,4) for(3,or,5) for(4,neg,7) for(6,neg,8) for(7,and,9) for(8,neg,11) for(9,neg,12) for(10,neg,13) for(12,neg,14) for(13,neg,15) for(15,neg,16) for(5,atom,q) for(11,atom,h) for(14,atom,v) for(16,atom,a)
# Optimization: -36
# Answer: 16 (Time: 0.926s)
# for(1,or,2) for(3,or,4) for(4,neg,6) for(5,neg,7) for(6,neg,8) for(7,neg,9) for(8,neg,10) for(9,and,11) for(10,neg,13) for(12,neg,14) for(13,neg,15) for(15,neg,16) for(2,atom,m) for(11,atom,k) for(14,atom,d) for(16,atom,m)
# Optimization: -37
# Answer: 17 (Time: 0.928s)
# for(1,or,2) for(3,or,4) for(4,neg,6) for(5,neg,7) for(6,neg,8) for(7,neg,9) for(8,neg,10) for(9,and,11) for(10,neg,13) for(12,neg,14) for(13,neg,15) for(15,neg,16) for(2,atom,r) for(11,atom,k) for(14,atom,o) for(16,atom,m)
# Optimization: -38
# Answer: 18 (Time: 2.854s)
# for(1,or,2) for(2,neg,4) for(3,neg,5) for(4,or,6) for(5,neg,8) for(6,neg,9) for(7,neg,10) for(8,or,11) for(9,and,13) for(10,neg,15) for(14,neg,16) for(11,atom,m) for(12,atom,r) for(13,atom,k) for(15,atom,r) for(16,atom,p)
# Optimization: -39
# Answer: 19 (Time: 3.656s)
# for(1,neg,2) for(2,neg,3) for(3,or,4) for(5,neg,6) for(6,or,7) for(8,or,9) for(9,neg,11) for(10,neg,12) for(12,neg,13) for(13,neg,14) for(14,or,15) for(4,atom,m) for(7,atom,c) for(11,atom,k) for(15,atom,g) for(16,atom,t)
# Optimization: -40
# Answer: 20 (Time: 10.525s)
# for(1,or,2) for(2,or,4) for(3,and,6) for(4,neg,8) for(5,or,9) for(7,neg,11) for(8,neg,12) for(11,and,13) for(13,neg,15) for(14,neg,16) for(6,atom,m) for(9,atom,p) for(10,atom,q) for(12,atom,k) for(15,atom,j) for(16,atom,h)
# Optimization: -41
# Answer: 21 (Time: 11.977s)
# for(1,and,2) for(2,or,4) for(3,or,6) for(4,neg,8) for(5,or,9) for(7,neg,11) for(8,neg,12) for(11,and,13) for(13,neg,15) for(14,neg,16) for(6,atom,u) for(9,atom,h) for(10,atom,v) for(12,atom,s) for(15,atom,k) for(16,atom,m)
# Optimization: -42
# Answer: 22 (Time: 11.986s)
# for(1,and,2) for(2,or,4) for(3,or,6) for(4,neg,8) for(5,or,9) for(7,neg,11) for(8,neg,12) for(11,and,13) for(13,neg,15) for(14,neg,16) for(6,atom,j) for(9,atom,k) for(10,atom,m) for(12,atom,p) for(15,atom,h) for(16,atom,v)
# Optimization: -43
# Answer: 23 (Time: 41.311s)
# for(1,and,2) for(2,neg,4) for(3,or,5) for(4,neg,7) for(6,or,8) for(7,or,10) for(9,and,12) for(11,or,14) for(13,neg,16) for(5,atom,f) for(8,atom,m) for(10,atom,h) for(12,atom,g) for(14,atom,a) for(15,atom,v) for(16,atom,a)
# Optimization: -44
# Answer: 24 (Time: 98.038s)
# for(1,and,2) for(2,or,4) for(3,or,6) for(5,and,8) for(7,or,10) for(8,or,12) for(9,or,14) for(15,neg,16) for(4,atom,m) for(6,atom,v) for(10,atom,h) for(11,atom,j) for(12,atom,g) for(13,atom,k) for(14,atom,f) for(16,atom,a)
# Optimization: -45
# Answer: 1 (Time: 118.641s)
# for(1,and,2) for(2,or,4) for(3,or,6) for(5,or,8) for(7,and,10) for(10,or,12) for(11,or,14) for(13,neg,16) for(4,atom,a) for(6,atom,m) for(8,atom,h) for(9,atom,v) for(12,atom,f) for(14,atom,g) for(15,atom,k) for(16,atom,a)
# Optimization: -45
# Answer: 2 (Time: 118.641s)
# for(1,and,2) for(2,or,4) for(3,or,6) for(5,or,8) for(7,and,10) for(10,or,12) for(11,or,14) for(13,neg,16) for(4,atom,j) for(6,atom,m) for(8,atom,h) for(9,atom,v) for(12,atom,f) for(14,atom,g) for(15,atom,k) for(16,atom,a)
# Optimization: -45
# Answer: 3 (Time: 118.641s)
# for(1,and,2) for(2,or,4) for(3,or,6) for(5,or,8) for(7,and,10) for(10,or,12) for(11,or,14) for(13,neg,16) for(4,atom,e) for(6,atom,m) for(8,atom,h) for(9,atom,v) for(12,atom,f) for(14,atom,g) for(15,atom,k) for(16,atom,a)
# Optimization: -45
# Answer: 4 (Time: 118.642s)
# for(1,and,2) for(2,or,4) for(3,or,6) for(5,or,8) for(7,and,10) for(10,or,12) for(11,or,14) for(13,neg,16) for(4,atom,h) for(6,atom,m) for(8,atom,e) for(9,atom,v) for(12,atom,f) for(14,atom,g) for(15,atom,k) for(16,atom,a)
# Optimization: -45
# Answer: 5 (Time: 118.642s)
# for(1,and,2) for(2,or,4) for(3,or,6) for(5,or,8) for(7,and,10) for(10,or,12) for(11,or,14) for(13,neg,16) for(4,atom,h) for(6,atom,m) for(8,atom,j) for(9,atom,v) for(12,atom,f) for(14,atom,g) for(15,atom,k) for(16,atom,a)
# Optimization: -45
# Answer: 6 (Time: 118.642s)
# for(1,and,2) for(2,or,4) for(3,or,6) for(5,or,8) for(7,and,10) for(10,or,12) for(11,or,14) for(13,neg,16) for(4,atom,h) for(6,atom,m) for(8,atom,a) for(9,atom,v) for(12,atom,f) for(14,atom,g) for(15,atom,k) for(16,atom,a)
# Optimization: -45
# Answer: 7 (Time: 118.642s)
# for(1,and,2) for(2,or,4) for(3,or,6) for(5,or,8) for(7,and,10) for(10,or,12) for(11,or,14) for(13,neg,16) for(4,atom,v) for(6,atom,m) for(8,atom,h) for(9,atom,j) for(12,atom,f) for(14,atom,g) for(15,atom,k) for(16,atom,a)
# Optimization: -45
# Answer: 8 (Time: 118.642s)
# for(1,and,2) for(2,or,4) for(3,or,6) for(5,or,8) for(7,and,10) for(10,or,12) for(11,or,14) for(13,neg,16) for(4,atom,v) for(6,atom,m) for(8,atom,e) for(9,atom,h) for(12,atom,f) for(14,atom,g) for(15,atom,k) for(16,atom,a)
# Optimization: -45
# Answer: 9 (Time: 118.643s)
# for(1,and,2) for(2,or,4) for(3,or,6) for(5,or,8) for(7,and,10) for(10,or,12) for(11,or,14) for(13,neg,16) for(4,atom,v) for(6,atom,m) for(8,atom,a) for(9,atom,h) for(12,atom,f) for(14,atom,g) for(15,atom,k) for(16,atom,a)
# Optimization: -45
# Answer: 10 (Time: 118.644s)
# for(1,and,2) for(2,or,4) for(3,or,6) for(5,or,8) for(7,and,10) for(10,or,12) for(11,or,14) for(15,neg,16) for(4,atom,a) for(6,atom,m) for(8,atom,h) for(9,atom,v) for(12,atom,g) for(13,atom,k) for(14,atom,f) for(16,atom,a)
# Optimization: -45
# Answer: 11 (Time: 118.644s)
# for(1,and,2) for(2,or,4) for(3,or,6) for(5,or,8) for(7,and,10) for(10,or,12) for(11,or,14) for(15,neg,16) for(4,atom,j) for(6,atom,m) for(8,atom,h) for(9,atom,v) for(12,atom,g) for(13,atom,k) for(14,atom,f) for(16,atom,a)
# Optimization: -45
# Answer: 12 (Time: 118.645s)
# for(1,and,2) for(2,or,4) for(3,or,6) for(5,or,8) for(7,and,10) for(10,or,12) for(11,or,14) for(15,neg,16) for(4,atom,e) for(6,atom,m) for(8,atom,h) for(9,atom,v) for(12,atom,g) for(13,atom,k) for(14,atom,f) for(16,atom,a)
# Optimization: -45
# Answer: 13 (Time: 118.645s)
# for(1,and,2) for(2,or,4) for(3,or,6) for(5,or,8) for(7,and,10) for(10,or,12) for(11,or,14) for(15,neg,16) for(4,atom,h) for(6,atom,m) for(8,atom,j) for(9,atom,v) for(12,atom,g) for(13,atom,k) for(14,atom,f) for(16,atom,a)
# Optimization: -45
# Answer: 14 (Time: 118.645s)
# for(1,and,2) for(2,or,4) for(3,or,6) for(5,or,8) for(7,and,10) for(10,or,12) for(11,or,14) for(15,neg,16) for(4,atom,h) for(6,atom,m) for(8,atom,e) for(9,atom,v) for(12,atom,g) for(13,atom,k) for(14,atom,f) for(16,atom,a)
# Optimization: -45
# Answer: 15 (Time: 118.645s)
# for(1,and,2) for(2,or,4) for(3,or,6) for(5,or,8) for(7,and,10) for(10,or,12) for(11,or,14) for(15,neg,16) for(4,atom,h) for(6,atom,m) for(8,atom,a) for(9,atom,v) for(12,atom,g) for(13,atom,k) for(14,atom,f) for(16,atom,a)
# Optimization: -45
# Answer: 16 (Time: 118.645s)
# for(1,and,2) for(2,or,4) for(3,or,6) for(5,or,8) for(7,and,10) for(10,or,12) for(11,or,14) for(15,neg,16) for(4,atom,v) for(6,atom,m) for(8,atom,h) for(9,atom,j) for(12,atom,g) for(13,atom,k) for(14,atom,f) for(16,atom,a)
# Optimization: -45
# Answer: 17 (Time: 118.646s)
# for(1,and,2) for(2,or,4) for(3,or,6) for(5,or,8) for(7,and,10) for(10,or,12) for(11,or,14) for(15,neg,16) for(4,atom,v) for(6,atom,m) for(8,atom,e) for(9,atom,h) for(12,atom,g) for(13,atom,k) for(14,atom,f) for(16,atom,a)
# Optimization: -45
# Answer: 18 (Time: 118.646s)
# for(1,and,2) for(2,or,4) for(3,or,6) for(5,or,8) for(7,and,10) for(10,or,12) for(11,or,14) for(15,neg,16) for(4,atom,v) for(6,atom,m) for(8,atom,a) for(9,atom,h) for(12,atom,g) for(13,atom,k) for(14,atom,f) for(16,atom,a)
# Optimization: -45
# Answer: 19 (Time: 118.746s)
# for(1,and,2) for(2,or,4) for(3,or,6) for(4,or,8) for(5,and,10) for(7,or,12) for(10,neg,14) for(11,or,15) for(6,atom,v) for(8,atom,f) for(9,atom,m) for(12,atom,h) for(13,atom,j) for(14,atom,a) for(15,atom,g) for(16,atom,u)
# Optimization: -45
# Answer: 20 (Time: 118.746s)
# for(1,and,2) for(2,or,4) for(3,or,6) for(4,or,8) for(5,and,10) for(7,or,12) for(10,neg,14) for(11,or,15) for(6,atom,v) for(8,atom,f) for(9,atom,m) for(12,atom,h) for(13,atom,j) for(14,atom,a) for(15,atom,g) for(16,atom,k)
# Optimization: -45
# Answer: 21 (Time: 118.747s)
# for(1,and,2) for(2,or,4) for(3,or,6) for(4,or,8) for(5,and,10) for(7,or,12) for(10,neg,14) for(11,or,15) for(6,atom,v) for(8,atom,f) for(9,atom,m) for(12,atom,e) for(13,atom,h) for(14,atom,a) for(15,atom,g) for(16,atom,u)
# Optimization: -45
# Answer: 22 (Time: 118.747s)
# for(1,and,2) for(2,or,4) for(3,or,6) for(4,or,8) for(5,and,10) for(7,or,12) for(10,neg,14) for(11,or,15) for(6,atom,v) for(8,atom,f) for(9,atom,m) for(12,atom,e) for(13,atom,h) for(14,atom,a) for(15,atom,g) for(16,atom,k)
# Optimization: -45
# Answer: 23 (Time: 118.747s)
# for(1,and,2) for(2,or,4) for(3,or,6) for(4,or,8) for(5,and,10) for(7,or,12) for(10,neg,14) for(11,or,15) for(6,atom,v) for(8,atom,f) for(9,atom,m) for(12,atom,a) for(13,atom,h) for(14,atom,a) for(15,atom,g) for(16,atom,u)
# Optimization: -45
# Answer: 24 (Time: 118.747s)
# for(1,and,2) for(2,or,4) for(3,or,6) for(4,or,8) for(5,and,10) for(7,or,12) for(10,neg,14) for(11,or,15) for(6,atom,v) for(8,atom,f) for(9,atom,m) for(12,atom,a) for(13,atom,h) for(14,atom,a) for(15,atom,g) for(16,atom,k)
# Optimization: -45
# Answer: 25 (Time: 118.748s)
# for(1,and,2) for(2,or,4) for(3,or,6) for(4,or,8) for(5,and,10) for(7,or,12) for(10,neg,14) for(11,or,15) for(6,atom,h) for(8,atom,f) for(9,atom,m) for(12,atom,j) for(13,atom,v) for(14,atom,a) for(15,atom,g) for(16,atom,u)
# Optimization: -45
# Answer: 26 (Time: 118.748s)
# for(1,and,2) for(2,or,4) for(3,or,6) for(4,or,8) for(5,and,10) for(7,or,12) for(10,neg,14) for(11,or,15) for(6,atom,h) for(8,atom,f) for(9,atom,m) for(12,atom,j) for(13,atom,v) for(14,atom,a) for(15,atom,g) for(16,atom,k)
# Optimization: -45
# Answer: 27 (Time: 118.748s)
# for(1,and,2) for(2,or,4) for(3,or,6) for(4,or,8) for(5,and,10) for(7,or,12) for(10,neg,14) for(11,or,15) for(6,atom,h) for(8,atom,f) for(9,atom,m) for(12,atom,e) for(13,atom,v) for(14,atom,a) for(15,atom,g) for(16,atom,u)
# Optimization: -45
# Answer: 28 (Time: 118.748s)
# for(1,and,2) for(2,or,4) for(3,or,6) for(4,or,8) for(5,and,10) for(7,or,12) for(10,neg,14) for(11,or,15) for(6,atom,h) for(8,atom,f) for(9,atom,m) for(12,atom,e) for(13,atom,v) for(14,atom,a) for(15,atom,g) for(16,atom,k)
# Optimization: -45
# Answer: 29 (Time: 118.749s)
# for(1,and,2) for(2,or,4) for(3,or,6) for(4,or,8) for(5,and,10) for(7,or,12) for(10,neg,14) for(11,or,15) for(6,atom,h) for(8,atom,f) for(9,atom,m) for(12,atom,a) for(13,atom,v) for(14,atom,a) for(15,atom,g) for(16,atom,u)
# Optimization: -45
# Answer: 30 (Time: 118.749s)
# for(1,and,2) for(2,or,4) for(3,or,6) for(4,or,8) for(5,and,10) for(7,or,12) for(10,neg,14) for(11,or,15) for(6,atom,h) for(8,atom,f) for(9,atom,m) for(12,atom,a) for(13,atom,v) for(14,atom,a) for(15,atom,g) for(16,atom,k)
# Optimization: -45
# Answer: 31 (Time: 118.749s)
# for(1,and,2) for(2,or,4) for(3,or,6) for(4,or,8) for(5,and,10) for(7,or,12) for(10,neg,14) for(11,or,15) for(6,atom,a) for(8,atom,f) for(9,atom,m) for(12,atom,h) for(13,atom,v) for(14,atom,a) for(15,atom,g) for(16,atom,u)
# Optimization: -45
# Answer: 32 (Time: 118.749s)
# for(1,and,2) for(2,or,4) for(3,or,6) for(4,or,8) for(5,and,10) for(7,or,12) for(10,neg,14) for(11,or,15) for(6,atom,a) for(8,atom,f) for(9,atom,m) for(12,atom,h) for(13,atom,v) for(14,atom,a) for(15,atom,g) for(16,atom,k)
# Optimization: -45
# Answer: 33 (Time: 118.750s)
# for(1,and,2) for(2,or,4) for(3,or,6) for(4,or,8) for(5,and,10) for(7,or,12) for(10,neg,14) for(11,or,15) for(6,atom,j) for(8,atom,f) for(9,atom,m) for(12,atom,h) for(13,atom,v) for(14,atom,a) for(15,atom,g) for(16,atom,u)
# Optimization: -45
# Answer: 34 (Time: 118.750s)
# for(1,and,2) for(2,or,4) for(3,or,6) for(4,or,8) for(5,and,10) for(7,or,12) for(10,neg,14) for(11,or,15) for(6,atom,j) for(8,atom,f) for(9,atom,m) for(12,atom,h) for(13,atom,v) for(14,atom,a) for(15,atom,g) for(16,atom,k)
# Optimization: -45
# Answer: 35 (Time: 118.750s)
# for(1,and,2) for(2,or,4) for(3,or,6) for(4,or,8) for(5,and,10) for(7,or,12) for(10,neg,14) for(11,or,15) for(6,atom,e) for(8,atom,f) for(9,atom,m) for(12,atom,h) for(13,atom,v) for(14,atom,a) for(15,atom,g) for(16,atom,u)
# Optimization: -45
# Answer: 36 (Time: 118.750s)
# for(1,and,2) for(2,or,4) for(3,or,6) for(4,or,8) for(5,and,10) for(7,or,12) for(10,neg,14) for(11,or,15) for(6,atom,e) for(8,atom,f) for(9,atom,m) for(12,atom,h) for(13,atom,v) for(14,atom,a) for(15,atom,g) for(16,atom,k)
# Optimization: -45
# *** Info : (clingo): INTERRUPTED by signal!
# OPTIMUM FOUND
#
# INTERRUPTED  : 1
# Models       : 60+
#   Optimum    : yes
#   Optimal    : 36
# Optimization : -45
# Calls        : 1
# Time         : 211.357s (Solving: 211.12s 1st Model: 0.37s Unsat: 0.00s)
# CPU Time     : 208.745s
# Process was interrupted.

# %%
# %%clingo --time-limit=300 --opt-mode=optN instances/instance-10-01.lp propositional.lp -
#
# #show failed/1.
# #show for/3.
# Out:
# clingo version 5.8.0
# Reading from instances/instance-10-01.lp ...
# Solving...
# Answer: 1 (Time: 0.027s)
# for(1,atom,d) failed(3) failed(5) failed(7) failed(6)
# Optimization: 4
# Answer: 2 (Time: 0.027s)
# for(1,atom,m) failed(5) failed(2)
# Optimization: 2
# Answer: 1 (Time: 0.028s)
# for(1,atom,m) failed(5) failed(2)
# Optimization: 2
# Answer: 2 (Time: 0.028s)
# for(1,atom,h) failed(5) failed(9)
# Optimization: 2
# OPTIMUM FOUND
#
# Models       : 4
#   Optimum    : yes
#   Optimal    : 2
# Optimization : 2
# Calls        : 1
# Time         : 0.028s (Solving: 0.00s 1st Model: 0.00s Unsat: 0.00s)
# CPU Time     : 0.026s
